# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

fontsize=15

data = pd.read_csv(r'C:\Users\devkh\Desktop\Phys 2925\e_m_experiment\data\5cm.csv')

mu_0 = 4 * np.pi * 10**(-7) # H/m

# %%
data.head()
# Out:
#    V_a (V)  d V_a (V)  I_H (A)  d I_H(A)  r (cm)  dr (cm)
# 0      500          2   1.9670    0.0002     5.0     0.05
# 1      490          2   1.9237    0.0002     5.0     0.05
# 2      480          2   1.9147    0.0002     5.0     0.05
# 3      470          2   1.8923    0.0002     5.0     0.05
# 4      460          2   1.8330    0.0002     5.0     0.05

# %%
data['r (m)'] = data['r (cm)'] / 100
data['dr (m)'] = data['dr (cm)'] / 100
data.head()
# Out:
#    V_a (V)  d V_a (V)  I_H (A)  d I_H(A)  r (cm)  dr (cm)  r (m)  dr (m)
# 0      500          2   1.9670    0.0002     5.0     0.05   0.05  0.0005
# 1      490          2   1.9237    0.0002     5.0     0.05   0.05  0.0005
# 2      480          2   1.9147    0.0002     5.0     0.05   0.05  0.0005
# 3      470          2   1.8923    0.0002     5.0     0.05   0.05  0.0005
# 4      460          2   1.8330    0.0002     5.0     0.05   0.05  0.0005

# %%
def magnetic_field(df, radius=5, N=2):
    '''Calculate the magnetic field around the Wehnelt cylinder.
    
    Parameters
    ----------
    df: pd.Dataframe containing the current measurements.
    radius: radius of the circle made by the electron beam.
    N: Number of turns around the coil.

    returns
    -------
    df: the dataframe containging the magnetic field and r^2 B^2
    '''
    k = (8 * mu_0 * N) / (np.sqrt(125) * radius)
    df['B (T)'] = k * df['I_H (A)']
    df['r^2 B^2 (m^2 T^2)'] = df['r (m)'] ** 2 + df['B (T)'] ** 2
    return df

data = magnetic_field(data, radius=5, N=2)
data
# Out:
#     V_a (V)  d V_a (V)  I_H (A)  d I_H(A)  r (cm)  dr (cm)  r (m)  dr (m)  \
# 0       500          2   1.9670    0.0002     5.0     0.05   0.05  0.0005
# 1       490          2   1.9237    0.0002     5.0     0.05   0.05  0.0005
# 2       480          2   1.9147    0.0002     5.0     0.05   0.05  0.0005
# 3       470          2   1.8923    0.0002     5.0     0.05   0.05  0.0005
# 4       460          2   1.8330    0.0002     5.0     0.05   0.05  0.0005
# 5       450          2   1.8329    0.0005     5.0     0.05   0.05  0.0005
# 6       440          2   1.7936    0.0002     5.0     0.05   0.05  0.0005
# 7       430          2   1.7610    0.0004     5.0     0.05   0.05  0.0005
# 8       420          2   1.7500    0.0003     5.0     0.05   0.05  0.0005
# 9       410          2   1.7230    0.0002     5.0     0.05   0.05  0.0005
# 10      400          2   1.6802    0.0004     5.0     0.05   0.05  0.0005
# 11      390          2   1.6644    0.0001     5.0     0.05   0.05  0.0005
# 12      380          2   1.6271    0.0002     5.0     0.05   0.05  0.0005
# 13      370          2   1.6020    0.0005     5.0     0.05   0.05  0.0005
# 14      360          2   1.5908    0.0002     5.0     0.05   0.05  0.0005
# 15      350          2   1.5735    0.0002     5.0     0.05   0.05  0.0005
# 16      340          2   1.5335    0.0004     5.0     0.05   0.05  0.0005
# 17      330          2   1.5029    0.0001     5.0     0.05   0.05  0.0005
# 18      320          2   1.4727    0.0002     5.0     0.05   0.05  0.0005
# 19      310          2   1.4507    0.0005     5.0     0.05   0.05  0.0005
# 20      300          2   1.3773    0.0003     5.0     0.05   0.05  0.0005
# 21      290          2   1.2350    0.0002     5.0     0.05   0.05  0.0005
# 22      280          2   1.2172    0.0002     5.0     0.05   0.05  0.0005
# 23      270          2   1.2224    0.0002     5.0     0.05   0.05  0.0005
# 24      260          2   1.5680    0.0002     5.0     0.05   0.05  0.0005
# 25      250          2   1.0945    0.0001     5.0     0.05   0.05  0.0005
# 26      240          2   1.0495    0.0003     5.0     0.05   0.05  0.0005
#
#            B (T)  r^2 B^2 (m^2 T^2)
# 0   7.074719e-07             0.0025
# 1   6.918982e-07             0.0025
# 2   6.886611e-07             0.0025
# 3   6.806045e-07             0.0025
# 4   6.592761e-07             0.0025
# 5   6.592401e-07             0.0025
# 6   6.451050e-07             0.0025
# 7   6.333798e-07             0.0025
# 8   6.294234e-07             0.0025
# 9   6.197123e-07             0.0025
# 10  6.043184e-07             0.0025
# 11  5.986356e-07             0.0025
# 12  5.852199e-07             0.0025
# 13  5.761922e-07             0.0025
# 14  5.721639e-07             0.0025
# 15  5.659416e-07             0.0025
# 16  5.515547e-07             0.0025
# 17  5.405488e-07             0.0025
# 18  5.296868e-07             0.0025
# 19  5.217740e-07             0.0025
# 20  4.953742e-07             0.0025
# 21  4.441931e-07             0.0025
# 22  4.377909e-07             0.0025
# 23  4.396612e-07             0.0025
# 24  5.639634e-07             0.0025
# 25  3.936594e-07             0.0025
# 26  3.774742e-07             0.0025

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 5))
sns.scatterplot(
    x=2*data['V_a (V)'], 
    y=data['r^2 B^2 (m^2 T^2)'],
    c='magenta',
    ax=ax
)
plt.show()

# %%
data.to_latex()
# Out:
# '\\begin{tabular}{lrrrrrrrrrr}\n\\toprule\n & V_a (V) & d V_a (V) & I_H (A) & d I_H(A) & r (cm) & dr (cm) & r (m) & dr (m) & B (T) & r^2 B^2 (m^2 T^2) \\\\\n\\midrule\n0 & 500 & 2 & 1.967000 & 0.000200 & 5.000000 & 0.050000 & 0.050000 & 0.000500 & 0.000001 & 0.002500 \\\\\n1 & 490 & 2 & 1.923700 & 0.000200 & 5.000000 & 0.050000 & 0.050000 & 0.000500 & 0.000001 & 0.002500 \\\\\n2 & 480 & 2 & 1.914700 & 0.000200 & 5.000000 & 0.050000 & 0.050000 & 0.000500 & 0.000001 & 0.002500 \\\\\n3 & 470 & 2 & 1.892300 & 0.000200 & 5.000000 & 0.050000 & 0.050000 & 0.000500 & 0.000001 & 0.002500 \\\\\n4 & 460 & 2 & 1.833000 & 0.000200 & 5.000000 & 0.050000 & 0.050000 & 0.000500 & 0.000001 & 0.002500 \\\\\n5 & 450 & 2 & 1.832900 & 0.000500 & 5.000000 & 0.050000 & 0.050000 & 0.000500 & 0.000001 & 0.002500 \\\\\n6 & 440 & 2 & 1.793600 & 0.000200 & 5.000000 & 0.050000 & 0.050000 & 0.000500 & 0.000001 & 0.002500 \\\\\n7 & 430 & 2 & 1.761000 & 0.000400 & 5.000000 & 0.050000 & 0.050000 & 0.000500 & 0.000001 & 0.002500 \\\\\n8 & 420 & 2 & 1.750000 & 0.000300 & 5.000000 & 0.050000 & 0.050000 & 0.000500 & 0.000001 & 0.002500 \\\\\n9 & 410 & 2 & 1.723000 & 0.000200 & 5.000000 & 0.050000 & 0.050000 & 0.000500 & 0.000001 & 0.002500 \\\\\n10 & 400 & 2 & 1.680200 & 0.000400 & 5.000000 & 0.050000 & 0.050000 & 0.000500 & 0.000001 & 0.002500 \\\\\n11 & 390 & 2 & 1.664400 & 0.000100 & 5.000000 & 0.050000 & 0.050000 & 0.000500 & 0.000001 & 0.002500 \\\\\n12 & 380 & 2 & 1.627100 & 0.000200 & 5.000000 & 0.050000 & 0.050000 & 0.000500 & 0.000001 & 0.002500 \\\\\n13 & 370 & 2 & 1.602000 & 0.000500 & 5.000000 & 0.050000 & 0.050000 & 0.000500 & 0.000001 & 0.002500 \\\\\n14 & 360 & 2 & 1.590800 & 0.000200 & 5.000000 & 0.050000 & 0.050000 & 0.000500 & 0.000001 & 0.002500 \\\\\n15 & 350 & 2 & 1.573500 & 0.000200 & 5.000000 & 0.050000 & 0.050000 & 0.000500 & 0.000001 & 0.002500 \\\\\n16 & 340 & 2 & 1.533500 & 0.000400 & 5.000000 & 0.050000 & 0.050000 & 0.000500 & 0.000001 & 0.002500 \\\\\n17 & 330 & 2 & 1.502900 & 0.000100 & 5.000000 & 0.050000 & 0.050000 & 0.000500 & 0.000001 & 0.002500 \\\\\n18 & 320 & 2 & 1.472700 & 0.000200 & 5.000000 & 0.050000 & 0.050000 & 0.000500 & 0.000001 & 0.002500 \\\\\n19 & 310 & 2 & 1.450700 & 0.000500 & 5.000000 & 0.050000 & 0.050000 & 0.000500 & 0.000001 & 0.002500 \\\\\n20 & 300 & 2 & 1.377300 & 0.000300 & 5.000000 & 0.050000 & 0.050000 & 0.000500 & 0.000000 & 0.002500 \\\\\n21 & 290 & 2 & 1.235000 & 0.000200 & 5.000000 & 0.050000 & 0.050000 & 0.000500 & 0.000000 & 0.002500 \\\\\n22 & 280 & 2 & 1.217200 & 0.000200 & 5.000000 & 0.050000 & 0.050000 & 0.000500 & 0.000000 & 0.002500 \\\\\n23 & 270 & 2 & 1.222400 & 0.000200 & 5.000000 & 0.050000 & 0.050000 & 0.000500 & 0.000000 & 0.002500 \\\\\n24 & 260 & 2 & 1.568000 & 0.000200 & 5.000000 & 0.050000 & 0.050000 & 0.000500 & 0.000001 & 0.002500 \\\\\n25 & 250 & 2 & 1.094500 & 0.000100 & 5.000000 & 0.050000 & 0.050000 & 0.000500 & 0.000000 & 0.002500 \\\\\n26 & 240 & 2 & 1.049500 & 0.000300 & 5.000000 & 0.050000 & 0.050000 & 0.000500 & 0.000000 & 0.002500 \\\\\n\\bottomrule\n\\end{tabular}\n'
